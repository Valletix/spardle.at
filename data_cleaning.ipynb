# %%
import pandas as pd
pd.options.display.max_rows = 64

df = pd.read_json("JSONS/products.json")
df.head(64)
# Out:
#     product_brand                                      product_name  \
# 0        S-BUDGET                             Fourré Biscuits Kakao
# 1        S-BUDGET                            Choco Nuts XXL Packung
# 2        S-BUDGET                          Kartoffel-Chips gesalzen
# 3        S-BUDGET                                     Marmor-Kuchen
# 4        S-BUDGET                                     Pommes Frites
# 5        S-BUDGET                                  Haselnuss Mignon
# 6        S-BUDGET  Schokoladen Waffelröllchen mit Milchcremefüllung
# 7        S-BUDGET                                Kakaokekse 4 x 45g
# 8        S-BUDGET                    Schoko-Milch Kekse 8 x 2 Stück
# 9        S-BUDGET                                       Knabber-Mix
# 10       S-BUDGET                             Stapel Chips Meersalz
# 11       S-BUDGET                                     Nuss-Küsschen
# 12       S-BUDGET                             Peanut Minis 20 Stück
# ...
